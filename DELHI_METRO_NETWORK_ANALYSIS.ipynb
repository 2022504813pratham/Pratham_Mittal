# %% [markdown]
# <a href="https://colab.research.google.com/github/2022504813pratham/Pratham_Mittal/blob/main/DELHI_METRO_NETWORK_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessary Python Libaries
import pandas as pd
import folium
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
# Loading my dataset
metro_data = pd.read_excel('metro_data.xlsx')
metro_data.sample(5)
# Out:
#      Station ID                 Station Name  Distance from Start (km)  \
# 61           62      Nangloi Railway Station                      11.2
# 88           89              Noida Sector 61                      50.5
# 258         259  Dilli Haat INA [Conn: Pink]                      23.8
# 109         110                  Nehru Place                      17.4
# 95           96                 Sector 55-66                       0.0
#
#             Line Opening Date Station Layout   Latitude  Longitude
# 61    Green line   2010-02-04       Elevated  28.682080  77.055960
# 88     Blue line   2019-09-03       Elevated  28.480863  77.084888
# 258  Yellow line   2010-03-09    Underground  28.575260  77.209350
# 109  Voilet line   2010-03-10       Elevated  28.551480  77.251540
# 95   Rapid Metro   2017-03-31       Elevated  28.493600  77.093500

# %%
# Converting Data type of my 'Opening Date' col in to Datetime Format
metro_data['Opening Date'] = pd.to_datetime(metro_data['Opening Date'])

# %%
# Overall view of the data (Cols and their datatype)
metro_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Station ID                285 non-null    int64
#  1   Station Name              285 non-null    object
#  2   Distance from Start (km)  285 non-null    float64
#  3   Line                      285 non-null    object
#  4   Opening Date              285 non-null    datetime64[ns]
#  5   Station Layout            285 non-null    object
#  6   Latitude                  285 non-null    float64
#  7   Longitude                 285 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 17.9+ KB

# %%
# To check if their is any Missing Values
metro_data.isnull().sum()
# Out:
# Station ID                  0
# Station Name                0
# Distance from Start (km)    0
# Line                        0
# Opening Date                0
# Station Layout              0
# Latitude                    0
# Longitude                   0
# dtype: int64

# %% [markdown]
# ### Removing Duplicates

# %%
duplicate_data = metro_data[metro_data.duplicated(subset=['Station Name'], keep=False)]
duplicate_data
# Out:
#      Station ID     Station Name  Distance from Start (km)               Line  \
# 115         116      Yamuna Bank                       0.0   Blue line branch
# 120         121  Ashok Park Main                       1.4         Green line
# 196         197  Ashok Park Main                       0.0  Green line branch
# 274         275      Yamuna Bank                      35.2          Blue line
#
#     Opening Date Station Layout  Latitude  Longitude
# 115   2009-10-05       At-Grade  28.62331   77.26792
# 120   2010-02-04       Elevated  28.67153   77.15527
# 196   2010-02-04       Elevated  28.67292   77.14420
# 274   2009-10-05       At-Grade  28.62331   77.26792

# %%
Station_Id = [116,197]
metro_data = metro_data[~metro_data['Station ID'].isin(Station_Id)]

# %%
# defining a color scheme for the metro lines
line_colors = {
    'Red line': 'red',
    'Blue line': 'blue',
    'Yellow line': 'beige',
    'Green line': 'green',
    'Voilet line': 'purple',
    'Pink line': 'pink',
    'Magenta line': 'darkred',
    'Orange line': 'orange',
    'Rapid Metro': 'cadetblue',
    'Aqua line': 'black',
    'Green line branch': 'lightgreen',
    'Blue line branch': 'lightblue',
    'Gray line': 'lightgray'
}

delhi_map_with_line_tooltip = folium.Map(location=[28.7041, 77.1025], zoom_start=11)

# adding colored markers for each metro station with line name in tooltip
for index, row in metro_data.iterrows():
    line = row['Line']
    color = line_colors.get(line, 'black')  # Default color is black if line not found in the dictionary
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Station Name']}",
        tooltip=f"{row['Station Name']}, {line}",
        icon=folium.Icon(color=color)
    ).add_to(delhi_map_with_line_tooltip)

# Displaying the updated map
delhi_map_with_line_tooltip
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c8ad63d711cade9bc66b049c0705acf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c8ad63d711cade9bc66b049c0705acf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c8ad63d711cade9bc66b049c0705acf = L.map(
#                 &quot;map_7c8ad63d711cade9bc66b049c0705acf&quot;,
#                 {
#                     center: [28.7041, 77.1025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6768c0474746e257c2777fed8ed99b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6768c0474746e257c2777fed8ed99b1.addTo(map_7c8ad63d711cade9bc66b049c0705acf);
#
#
#             var marker_a3c1866249dc0aa87aed34a6b266c35f = L.marker(
#                 [28.67579, 77.31239],
#                 {}
#             ).addTo(map_7c8ad63d711cade9bc66b049c0705acf);
#
#
#             var icon_8014703f0cb9294feb8c7d69e97e53b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a3c1866249dc0aa87aed34a6b266c35f.setIcon(icon_8014703f0cb9294feb8c7d69e97e53b2);
#
#
#         var popup_8924dc1cc584cdafc06114635aa8fb7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_380846f304b78dbd98982b87fc327e88 = $(`&lt;div id=&quot;html_380846f304b78dbd98982b87fc327e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jhil Mil&lt;/div&gt;`)[0];
#                 popup_8924dc1cc584cdafc06114635aa8fb7e.setContent(html_380846f304b78dbd98982b87fc327e88);
#
#
#
#         marker_a3c1866249dc0aa87aed34a6b266c35f.bindPopup(popup_8924dc1cc584cdafc06114635aa8fb7e)
#         ;
#
#
#
#
#             marker_a3c1866249dc0aa87aed34a6b266c35f.bindTooltip(
#                 `&lt;div&gt;
#                      Jhil Mil, Red line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d503f96601a629efdd5da042e8ea7fb2 = L.marker(
#                 [28.6718, 77.27756],
#                 {}
#             ).addTo(map_7c8ad63d711cade9bc66b049c0705acf);
#
#
#             var icon_1139178ecc8d83c2c6b30253f31079d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d503f96601a629efdd5da042e8ea7fb2.setIcon(icon_1139178ecc8d83c2c6b30253f31079d2);
#
#
#         var popup_e5008900f2e0cd1c641c62dceb4874ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62b3dbdd997bae6ff9e6344310135f77 = $(`&lt;div id=&quot;html_62b3dbdd997bae6ff9e6344310135f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome [Conn: Red]&lt;/div&gt;`)[0];
#                 popup_e5008900f2e0cd1c641c62dceb4874ed.setContent(html_62b3dbdd997bae6ff9e6344310135f77);
#
#
#
#         marker_d503f96601a629efdd5da042e8ea7fb2.bindPopup(popup_e5008900f2e0cd1c641c62dceb4874ed)
#         ;
#
#
#
#
#             marker_d503f96601a629efdd5da042e8ea7fb2.bindTooltip(
#                 `&lt;div&gt;
#                      Welcome [Conn: Red], Pink line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6d73ffe0c531c132dc6fab389bef5cc0 = L.marker(
#                 [28.4936, 77.0935],
#                 {}
#             ).addTo(map_7c8ad63d711cade9bc66b049c0705acf);
#
#
#             var icon_0cba0f7c830c88b774baff4c36ece983 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d73ffe0c531c132dc6fab389bef5cc0.setIcon(icon_0cba0f7c830c88b774baff4c36ece983);
#
#
#         var popup_2fc5e84bae9692a2446e06e6eb82c946 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_284289b0c4bc887aebac92d3cc8e9996 = $(`&lt;div id=&quot;html_284289b0c4bc887aebac92d3cc8e9996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DLF Phase 3&lt;/div&gt;`)[0];
#                 popup_2fc5e84bae9692a2446e06e6eb82c946.setContent(html_284289b0c4bc887aebac92d3cc8e9996);
#
#
#
#         marker_6d73ffe0c531c132dc6fab389bef5cc0.bindPopup(popup_2fc5e84bae9692a2446e

# %% [markdown]
# # We have to update metro station Coordinates because of their wrong positions in map can be seen above 🗺📌

# %%
file_path = "metro_data.xlsx"
metro_data.to_excel(file_path, index = False)

# %%
from IPython.display import FileLink
FileLink(file_path)
# Out:
# /content/metro_data.xlsx

# %%
metro_data.loc[metro_data['Station Name'] == 'Sarai', ['Latitude', 'Longitude']] = [28.4776218,77.3042433]

# %%
metro_data[metro_data['Station Name'] =='Kashmere Gate [Conn: Violet,Yellow]']
# Out:
#     Station ID                         Station Name  Distance from Start (km)  \
# 66          67  Kashmere Gate [Conn: Violet,Yellow]                      18.5
#
#         Line Opening Date Station Layout  Latitude  Longitude
# 66  Red line   2002-12-24       Elevated   28.6675   77.22817

# %%
metro_data[metro_data['Line']=='Rapid Metro']
# Out:
#      Station ID                Station Name  Distance from Start (km)  \
# 2             3                 DLF Phase 3                      10.0
# 18           19            Belvedere Towers                       8.0
# 84           85  Sikandarpur [Conn: Yellow]                       6.6
# 95           96                Sector 55-66                       0.0
# 117         118                  Cyber City                       8.6
# 146         147             Sector 54 Chowk                       1.1
# 167         168                Sector 42-43                       3.9
# 194         195             Moulsari Avenue                       9.2
# 198         199                 DLF Phase 2                       7.3
# 271         272                Sector 53-54                       2.6
# 273         274                 DLF Phase 1                       5.5
#
#             Line Opening Date Station Layout  Latitude  Longitude
# 2    Rapid Metro   2013-11-14       Elevated   28.4936    77.0935
# 18   Rapid Metro   2013-11-14       Elevated   28.4936    77.0935
# 84   Rapid Metro   2013-11-14       Elevated   28.4936    77.0935
# 95   Rapid Metro   2017-03-31       Elevated   28.4936    77.0935
# 117  Rapid Metro   2014-07-05       Elevated   28.4936    77.0935
# 146  Rapid Metro   2017-03-31       Elevated   28.4936    77.0935
# 167  Rapid Metro   2017-04-25       Elevated   28.4936    77.0935
# 194  Rapid Metro   2013-11-14       Elevated   28.4936    77.0935
# 198  Rapid Metro   2013-11-14       Elevated   28.4936    77.0935
# 271  Rapid Metro   2017-04-25       Elevated   28.4936    77.0935
# 273  Rapid Metro   2017-03-31       Elevated   28.4936    77.0935

# %%
metro_data[metro_data['Station Name'] == 'NSEZ Noida']
# Out:
#      Station ID Station Name  Distance from Start (km)       Line  \
# 210         211   NSEZ Noida                       6.3  Aqua line
#
#     Opening Date Station Layout   Latitude  Longitude
# 210   2019-01-25       Elevated  28.535517  77.391029

# %% [markdown]
# # New Updated DataFrame 👇👇

# %%
metro_data = pd.read_excel('metro_data12.xlsx')
metro_data
# Out:
#      Station ID           Station Name  Distance from Start (km)  \
# 0             1               Jhil Mil                      10.3
# 1             2    Welcome [Conn: Red]                      46.8
# 2             3            DLF Phase 3                      10.0
# 3             4             Okhla NSIC                      23.8
# 4             5             Dwarka Mor                      10.2
# ..          ...                    ...                       ...
# 282         283        Noida Sector 18                      43.6
# 283         284      Knowledge Park II                      21.4
# 284         285  Mayur Vihar Extention                      39.5
# 285         286  Noida Electronic City                      53.5
# 286         287       Dhansa Bus Stand                       5.1
#
#              Line         Opening Date Station Layout   Latitude  Longitude
# 0        Red line           2008-04-06       Elevated  28.675790  77.312390
# 1       Pink line           2018-10-31       Elevated  28.671800  77.277560
# 2     Rapid Metro           2013-11-14       Elevated  28.493670  77.088540
# 3    Magenta line           2017-12-25       Elevated  28.554483  77.264849
# 4       Blue line           2005-12-30       Elevated  28.619320  77.033260
# ..            ...                  ...            ...        ...        ...
# 282     Blue line           2009-12-11       Elevated  28.570810  77.326120
# 283     Aqua line           2019-01-25       Elevated  28.456867  77.500054
# 284     Blue line           2009-12-11       Elevated  28.594158  77.294589
# 285     Blue line           2019-09-03       Elevated  28.627385  77.372518
# 286     Gray line  2021-09-18 00:00:00    Underground  28.610745  76.976476
#
# [287 rows x 8 columns]

# %%
import folium

# Defining a color scheme for the metro lines
line_colors = {
    'Red line': 'red',
    'Blue line': 'blue',
    'Yellow line': 'beige',
    'Green line': 'green',
    'Voilet line': 'purple',
    'Pink line': 'pink',
    'Magenta line': 'darkred',
    'Orange line': 'orange',
    'Rapid Metro': 'cadetblue',
    'Aqua line': 'black',
    'Green line branch': 'lightgreen',
    'Blue line branch': 'lightblue',
    'Gray line': 'lightgray'
}

# Creating a map centered on Delhi
delhi_map_with_line_tooltip = folium.Map(location=[28.7041, 77.1025], zoom_start=11)

# Adding colored markers for each metro station with line name in tooltip
for index, row in metro_data.iterrows():
    line = row['Line']
    color = line_colors.get(line, 'black')  # Default color is black if line not found in the dictionary
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Station Name']}",
        tooltip=f"{row['Station Name']}, {line}",
        icon=folium.Icon(color=color)
    ).add_to(delhi_map_with_line_tooltip)

# Drawing a single continuous line for Orange line stations in the order of Distance from Start (km)
orange_line_stations = metro_data[metro_data['Line'] == 'Orange line'].sort_values(by='Distance from Start (km)')
coordinates = orange_line_stations[['Latitude', 'Longitude']].values.tolist()

# Adding a PolyLine to the map
folium.PolyLine(locations=coordinates, color='orange', weight=5).add_to(delhi_map_with_line_tooltip)

# Displaying the updated map
delhi_map_with_line_tooltip
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d4d61267db58aa6efde9899b2b2f473 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d4d61267db58aa6efde9899b2b2f473&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d4d61267db58aa6efde9899b2b2f473 = L.map(
#                 &quot;map_1d4d61267db58aa6efde9899b2b2f473&quot;,
#                 {
#                     center: [28.7041, 77.1025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1111fcc73d7ad8575510ae83077ab39b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1111fcc73d7ad8575510ae83077ab39b.addTo(map_1d4d61267db58aa6efde9899b2b2f473);
#
#
#             var marker_c89dcef44dcb4809bed037b6d384f331 = L.marker(
#                 [28.67579, 77.31239],
#                 {}
#             ).addTo(map_1d4d61267db58aa6efde9899b2b2f473);
#
#
#             var icon_4fb9530672d626a6d4a91643410c8c34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c89dcef44dcb4809bed037b6d384f331.setIcon(icon_4fb9530672d626a6d4a91643410c8c34);
#
#
#         var popup_ef205714f705857a89d38dca200f2e4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e2bd58215768df70e35d6e1b723caec = $(`&lt;div id=&quot;html_5e2bd58215768df70e35d6e1b723caec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jhil Mil&lt;/div&gt;`)[0];
#                 popup_ef205714f705857a89d38dca200f2e4e.setContent(html_5e2bd58215768df70e35d6e1b723caec);
#
#
#
#         marker_c89dcef44dcb4809bed037b6d384f331.bindPopup(popup_ef205714f705857a89d38dca200f2e4e)
#         ;
#
#
#
#
#             marker_c89dcef44dcb4809bed037b6d384f331.bindTooltip(
#                 `&lt;div&gt;
#                      Jhil Mil, Red line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_22d6d8dc63d40d77dc4fabb0245f1dee = L.marker(
#                 [28.6718, 77.27756],
#                 {}
#             ).addTo(map_1d4d61267db58aa6efde9899b2b2f473);
#
#
#             var icon_89b032933ddb4ccb726cf5f65df907a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_22d6d8dc63d40d77dc4fabb0245f1dee.setIcon(icon_89b032933ddb4ccb726cf5f65df907a8);
#
#
#         var popup_b621f7168d87d70c1e71d5c780b63a8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_edb78d3faafd9f186850ea4250f09c80 = $(`&lt;div id=&quot;html_edb78d3faafd9f186850ea4250f09c80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome [Conn: Red]&lt;/div&gt;`)[0];
#                 popup_b621f7168d87d70c1e71d5c780b63a8d.setContent(html_edb78d3faafd9f186850ea4250f09c80);
#
#
#
#         marker_22d6d8dc63d40d77dc4fabb0245f1dee.bindPopup(popup_b621f7168d87d70c1e71d5c780b63a8d)
#         ;
#
#
#
#
#             marker_22d6d8dc63d40d77dc4fabb0245f1dee.bindTooltip(
#                 `&lt;div&gt;
#                      Welcome [Conn: Red], Pink line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6dea006316ff61c7213d8942135338f9 = L.marker(
#                 [28.49367, 77.08854],
#                 {}
#             ).addTo(map_1d4d61267db58aa6efde9899b2b2f473);
#
#
#             var icon_b14f6feb3e0badf1175dbcad4d75925d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6dea006316ff61c7213d8942135338f9.setIcon(icon_b14f6feb3e0badf1175dbcad4d75925d);
#
#
#         var popup_dc1c1d3509109ec3f1ade28be6a72b32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_caff861191e9294e1bab7477878d7830 = $(`&lt;div id=&quot;html_caff861191e9294e1bab7477878d7830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DLF Phase 3&lt;/div&gt;`)[0];
#                 popup_dc1c1d3509109ec3f1ade28be6a72b32.setContent(html_caff861191e9294e1bab7477878d7830);
#
#
#
#         marker_6dea006316ff61c7213d8942135338f9.bindPopup(popup_dc1c1d3509109ec3f1

# %%
# Converting Data type of my 'Opening Date' col in to Datetime Format
metro_data['Opening Date'] = pd.to_datetime(metro_data['Opening Date'])

# %%
metro_data['Opening Year'] = metro_data['Opening Date'].dt.year

# counting the number of stations opened each year
stations_per_year = metro_data['Opening Year'].value_counts().sort_index()

stations_per_year_df = stations_per_year.reset_index()
stations_per_year_df.columns = ['Year', 'Number of Stations']

# %%
fig = px.bar(stations_per_year_df, x='Year', y='Number of Stations',
             title="Number of Metro Stations Opened Each Year in Delhi NCR",
             labels={'Year': 'Year', 'Number of Stations': 'Number of Stations Opened'},
             color='Number of Stations', color_continuous_scale='Solar')

fig.update_layout(xaxis_tickangle=-45, xaxis=dict(tickmode='linear'),
                  yaxis=dict(title='Number of Stations Opened'),
                  xaxis_title="Year")

# Adding annotations for significant years
significant_years = stations_per_year_df[stations_per_year_df['Number of Stations'] > 40]
for i, row in significant_years.iterrows():
    fig.add_annotation(x=row['Year'], y=row['Number of Stations'],
                       text=f"{row['Number of Stations']} stations",
                       showarrow=True, arrowhead=1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a494c4c2-cf05-417d-bda0-31a8a7ecc187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a494c4c2-cf05-417d-bda0-31a8a7ecc187")) {                    Plotly.newPlot(                        "a494c4c2-cf05-417d-bda0-31a8a7ecc187",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}\u003cbr\u003eNumber of Stations Opened=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[6,4,11,28,9,3,17,54,13,5,3,13,18,64,38,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2002,2003,2004,2005,2006,2008,2009,2010,2011,2013,2014,2015,2017,2018,2019,2021],"xaxis":"x","y":[6,4,11,28,9,3,17,54,13,5,3,13,18,64,38,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5}," ...

# %% [markdown]
# ### The bar chart illustrates the number of Delhi Metro stations opened each year.
# #### Conversely, there are years with few or no new stations, which could be due to various factors like planning, funding, or construction challenges

# %% [markdown]
# ## Metro lines in terms of the number of stations they have and the average distance between stations.
# #### It will give us insights into the characteristics of each metro line, such as which lines are more extensive or denser.

# %%
stations_per_line = metro_data['Line'].value_counts()

# calculating the total distance of each metro line (max distance from start)
total_distance_per_line = metro_data.groupby('Line')['Distance from Start (km)'].max()

avg_distance_per_line = total_distance_per_line / (stations_per_line - 1)

line_analysis = pd.DataFrame({
    'Line': stations_per_line.index,
    'Number of Stations': stations_per_line.values,
    'Average Distance Between Stations (km)': avg_distance_per_line
})

# sorting the DataFrame by the number of stations
line_analysis = line_analysis.sort_values(by='Number of Stations', ascending=False)

line_analysis.reset_index(drop=True, inplace=True)
pd.DataFrame(line_analysis)
# Out:
#                  Line  Number of Stations  \
# 0           Blue line                  50
# 1           Pink line                  38
# 2         Yellow line                  37
# 3         Voilet line                  34
# 4            Red line                  29
# 5        Magenta line                  25
# 6           Aqua line                  21
# 7          Green line                  21
# 8         Rapid Metro                  11
# 9    Blue line branch                   8
# 10        Orange line                   6
# 11          Gray line                   4
# 12  Green line branch                   3
#
#     Average Distance Between Stations (km)
# 0                                 1.355000
# 1                                 1.091837
# 2                                 1.157143
# 3                                 1.700000
# 4                                 1.240000
# 5                                 1.050000
# 6                                 1.379167
# 7                                 4.160000
# 8                                 1.421622
# 9                                 1.000000
# 10                                1.167857
# 11                                1.318182
# 12                                1.269444

# %%
# creating subplots
fig = make_subplots(rows=1, cols=2, subplot_titles=('Number of Stations Per Metro Line',
                                                    'Average Distance Between Stations Per Metro Line'),
                    horizontal_spacing=0.2)

# plot for Number of Stations per Line
fig.add_trace(
    go.Bar(y=line_analysis['Line'], x=line_analysis['Number of Stations'],
           orientation='h', name='Number of Stations', marker_color='crimson'),
    row=1, col=1
)

# plot for Average Distance Between Stations
fig.add_trace(
    go.Bar(y=line_analysis['Line'], x=line_analysis['Average Distance Between Stations (km)'],
           orientation='h', name='Average Distance (km)', marker_color='navy'),
    row=1, col=2
)

# update xaxis properties
fig.update_xaxes(title_text="Number of Stations", row=1, col=1)
fig.update_xaxes(title_text="Average Distance Between Stations (km)", row=1, col=2)

# update yaxis properties
fig.update_yaxes(title_text="Metro Line", row=1, col=1)
fig.update_yaxes(title_text="", row=1, col=2)

# update layout
fig.update_layout(height=600, width=1200, title_text="Metro Line Analysis", template="plotly_white")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f40e96a1-973a-48b1-bd0c-13f003c8340a" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f40e96a1-973a-48b1-bd0c-13f003c8340a")) {                    Plotly.newPlot(                        "f40e96a1-973a-48b1-bd0c-13f003c8340a",                        [{"marker":{"color":"crimson"},"name":"Number of Stations","orientation":"h","x":[50,38,37,34,29,25,21,21,11,8,6,4,3],"y":["Blue line","Pink line","Yellow line","Voilet line","Red line","Magenta line","Aqua line","Green line","Rapid Metro","Blue line branch","Orange line","Gray line","Green line branch"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"navy"},"name":"Average Distance (km)","orientation":"h","x":[1.355,1.0918367346938775,1.157142857142857,1.7,1.24,1.05,1.3791666666666667,4.16,1.4216216216216218,1.0,1.167857142857143,1.3181818181818181,1.2694444444444446],"y":["Blue line","Pink line","Yellow line","Voilet line","Red line","Magenta line","Aqua line","Green line","Rapid Metro","Blue line branch","Orange line","Gray line","Green line branch"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{ ...

# %% [markdown]
# ## Exploring the station layouts (Elevated, Ground Level, Underground).
#
# ####  Analyzing the distribution of these layouts across the network and see if there are any patterns or trends, such as certain lines favouring a particular layout.

# %%
layout_counts = metro_data['Station Layout'].value_counts()

# creating the bar plot using Plotly
fig = px.bar(x=layout_counts.index, y=layout_counts.values,
             labels={'x': 'Station Layout', 'y': 'Number of Stations'},
             title='Distribution of Delhi Metro Station Layouts',
             color=layout_counts.index,
             color_continuous_scale='pastel')

# updating layout for better presentation
fig.update_layout(xaxis_title="Station Layout",
                  yaxis_title="Number of Stations",
                  coloraxis_showscale=False,
                  template="plotly_white")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2172b70d-5f5a-49f0-b8b0-44924ccd6afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2172b70d-5f5a-49f0-b8b0-44924ccd6afb")) {                    Plotly.newPlot(                        "2172b70d-5f5a-49f0-b8b0-44924ccd6afb",                        [{"alignmentgroup":"True","hovertemplate":"color=Elevated\u003cbr\u003eStation Layout=%{x}\u003cbr\u003eNumber of Stations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Elevated","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Elevated","offsetgroup":"Elevated","orientation":"v","showlegend":true,"textposition":"auto","x":["Elevated"],"xaxis":"x","y":[215],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Underground\u003cbr\u003eStation Layout=%{x}\u003cbr\u003eNumber of Stations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Underground","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Underground","offsetgroup":"Underground","orientation":"v","showlegend":true,"textposition":"auto","x":["Underground"],"xaxis":"x","y":[69],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=At-Grade\u003cbr\u003eStation Layout=%{x}\u003cbr\u003eNumber of Stations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At-Grade","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"At-Grade","offsetgroup":"At-Grade","orientation":"v","showlegend":true,"textposition":"auto","x":["At-Grade"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %%
metro_data[metro_data['Station Layout'] == 'At-Grade']
# Out:
#      Station ID              Station Name  Distance from Start (km)  \
# 111         112  Kirti Nagar [Conn: Blue]                       2.1
# 274         275               Yamuna Bank                      35.2
#
#                   Line Opening Date Station Layout  Latitude  Longitude  \
# 111  Green line branch   2011-08-27       At-Grade  28.65575   77.15057
# 274          Blue line   2009-10-05       At-Grade  28.62331   77.26792
#
#      Opening Year
# 111          2011
# 274          2009

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Metro Network Analysis involves examining the network of metro systems to understand their structure, efficiency, and effectiveness.
# #### It typically includes analyzing routes, stations, traffic, connectivity, and other operational aspects.
